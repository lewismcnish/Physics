# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt


TITLE_SIZE = 20
AXIS_SIZE = 16
plt.rcParams["font.family"] = "Times New Roman"

# %%
pcts = [27, 68, 5]
plt.figure(figsize=(10, 10))
plt.pie(pcts, labels=[ "Dark Matter", "Dark Energy", "Visible Matter"], autopct='%1.1f%%', shadow=True, startangle=90, colors= ['#141414', 'indigo', 'blue'], explode=[0.1, 0, 0],labeldistance=None,radius=1.2,textprops={'fontsize': 25,'color':'white'})
plt.legend(prop={'size': 20})
plt.show()
