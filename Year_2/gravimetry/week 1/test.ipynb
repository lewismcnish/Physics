# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

# %%
time = np.linspace(0,1000,1)
data = np.loadtxt('EllasData.txt',skiprows = 2)
time = data[:,0]
x_pos = data[:,1]
plt.figure()
plt.plot(time, x_pos)
plt.show()


peaks = sp.signal.find_peaks(x_pos, height = 0.25, distance = 100)
print(peaks)
# Out:
# (array([ 71, 216, 359, 507, 650]), {'peak_heights': array([0.325, 0.319, 0.318, 0.321, 0.32 ])})
