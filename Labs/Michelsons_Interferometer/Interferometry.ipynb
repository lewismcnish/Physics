# %% [markdown]
# # Michelson's Interferometer
#
# Matric: 2663452m
#
# ## Overview
#
# In this lab we are required to calibrate the Michelson's Interferometer and use it to measure the wavelength of a green laser. Then use it to measure the spectral width of a green, red and white laser. Finally we are required to use the interferometer to measure the refractive index of a perspex block.
#
#
# ## Pre lab questions:
#
# b) If you observe a green laser (λ = 532nm) and move one of the interferometer mirrors by 1µm,
# by how many fringes does the observed pattern shift?
#
# $$Path Difference = r_2 - r_1 = d\sin\theta = m\lambda $$
# For $λ = 532nm$ <br>
# $r_1 = x$ <br> $r_2 = x+1µm$ <br>
# $r_2 - r_1 = 1\mu = m\lambda$ <br>
# $1\mu m = m532nm$ <br>
# $m = \frac{1\mu m}{532nm} = 1.88$ <br>
#
# For 1 mirror to move by 1µm, the pattern shifts by 1.88 fringes.
#
#
#
# c) In 2 cells below <br>
# d) In 2 cells below <br>
# As the second mirror is moved the intensity of the light is reduced as the light is no longer in phase and is desctructively interefering. <br>

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import os
import scipy.optimize as opt
from scipy.signal import find_peaks

title_size = 18
axis_size = 14

# %%
# def intensity(d, lam):
#     return np.sin(2*np.pi*d/(lam))**2
# def totIntensity(d, lam1, lam2):
#     return intensity(d, lam1) + intensity(d, lam2)

# lam = 530e-9
# lam2 = 535e-9
# d= np.linspace(1e-6, 5e-6, 1000)
# d2 = np.linspace(1e-6, 50e-6, 10000)

# # plt.figure()
# # plt.plot(d, intensity(d, lam))
# # plt.title('Intensity vs. Distance', fontsize=title_size)
# # plt.xlabel(r'Distance ($\mu$m)', fontsize=axis_size)
# # plt.ylabel('Intensity (arb. units)', fontsize=axis_size)
# # plt.show()

# plt.figure()
# plt.plot(d2, totIntensity(d2, lam, lam2))|
# plt.title('Total Intensity vs. Distance', fontsize=title_size)
# plt.xlabel(r'Distance ($\mu$m)', fontsize=axis_size)
# plt.xticks(np.arange(0, 55e-6, 5e-6))
# plt.ylabel('Intensity (arb. units)', fontsize=axis_size)
# plt.show()

# %%
def amplitude(d, lam):
    return (np.sin(2*np.pi*d/(lam)))

def totAmplitude(d, lam1, lam2):
    return (np.abs(amplitude(d, lam1) + amplitude(d, lam2)))**2
def int_from_amp(d, lam):
    return (np.abs(amplitude(d, lam)))**2

lam = 530e-9
lam2 = 535e-9
d= np.linspace(1e-6, 5e-6, 1000)
d2 = np.linspace(1e-6, 100e-6, 100000)

plt.figure()
plt.plot(d, int_from_amp(d, lam))
plt.title('Intensity vs. Distance', fontsize=title_size)
plt.xlabel(r'Distance ($\mu$m)', fontsize=axis_size)
plt.ylabel('Intensity (arb. units)', fontsize=axis_size)
plt.show()

plt.figure()
plt.plot(d2, totAmplitude(d2, lam, lam2))
plt.title('Total Intensity vs. Distance', fontsize=title_size)
plt.xlabel(r'Distance ($\mu$m)', fontsize=axis_size)
#plt.xticks(np.arange(0, 55e-6, 5e-6))
#plt.xlim(80e-6, 90e-6)
plt.ylabel('Intensity (arb. units)', fontsize=axis_size)
plt.show()

# x = totAmplitude(d2, lam, lam2)
# peaks, _ = find_peaks(-x, height=np.min(totAmplitude(d2, lam, lam2)))
# plt.plot(x)
# plt.plot(peaks, x[peaks], "x")
# plt.plot(np.zeros_like(x), "--", color="gray")
# plt.show()

# print(peaks)

# print(np.min(totAmplitude(d2, lam, lam2)))
# print(d2[np.where(x == np.min(totAmplitude(d2, lam, lam2)))])

# %% [markdown]
# # Task 5.2

# %%
def amplitude(d, lam):
    return (np.sin(2*np.pi*d/(lam)))

def totAmplitude(d, lam1, lam2):
    return (np.abs(amplitude(d, lam1) + amplitude(d, lam2)))**2
def int_from_amp(d, lam):
    return (np.abs(amplitude(d, lam)))**2

lam = 530e-9
lam2 = 530.8e-9
d= np.linspace(1e-6, 5e-6, 1000)
d2 = np.linspace(0e-6, 450e-6, 100000)

plt.figure()
plt.plot(d, int_from_amp(d, lam))
plt.title('Intensity vs. Distance', fontsize=title_size)
plt.xlabel(r'Distance ($\mu$m)', fontsize=axis_size)
plt.ylabel('Intensity (arb. units)', fontsize=axis_size)
plt.show()
#### plot of the model as observed from the laser
plt.figure()
plt.plot(d2, totAmplitude(d2, lam, lam2))
plt.title('Total Intensity vs. Distance', fontsize=title_size)
plt.xlabel(r'Distance ($\mu$m)', fontsize=axis_size)
#plt.xticks(np.arange(0, 55e-6, 5e-6))
#plt.xlim(80e-6, 90e-6)
plt.ylabel('Intensity (arb. units)', fontsize=axis_size)
plt.show()

# x = totAmplitude(d2, lam, lam2)
# peaks, _ = find_peaks(-x, height=np.min(totAmplitude(d2, lam, lam2)))
# plt.plot(x)
# plt.plot(peaks, x[peaks], "x")
# plt.plot(np.zeros_like(x), "--", color="gray")
# plt.show()

# print(peaks)

# print(np.min(totAmplitude(d2, lam, lam2)))
# print(d2[np.where(x == np.min(totAmplitude(d2, lam, lam2)))])

# %% [markdown]
# # Task 6

# %%
def amplitude(d, lam):
    return (np.sin(2*np.pi*d/(lam)))
def totAmplitude(d, lam1, lam2):
    return (np.abs(amplitude(d, lam1) + amplitude(d, lam2)))**2
def int_from_amp(d, lam):
    return (np.abs(amplitude(d, lam)))**2

lam = 300e-9
lam2 = 305e-9
d= np.linspace(1e-6, 5e-6, 1000)
d2 = np.linspace(1e-6, 300e-6, 100000)

plt.figure()
plt.plot(d, int_from_amp(d, lam))
plt.title('Intensity vs. Distance', fontsize=title_size)
plt.xlabel(r'Distance ($\mu$m)', fontsize=axis_size)
plt.ylabel('Intensity (arb. units)', fontsize=axis_size)
plt.show()

plt.figure()
plt.plot(d2, totAmplitude(d2, lam, lam2))
plt.title('Total Intensity vs. Distance', fontsize=title_size)
plt.xlabel(r'Distance ($\mu$m)', fontsize=axis_size)
#plt.xticks(np.arange(0, 55e-6, 5e-6))
plt.xlim(0e-6, 40e-6)
plt.ylabel('Intensity (arb. units)', fontsize=axis_size)
plt.show()

# %% [markdown]
# # Task 7
# 3)  Distinct fringe pattern with lots of different wavelengths of light visible at different angles

# %% [markdown]
# # Task 5.1.3
#
# Use data to calculate wavelength of light.

# %%
fringe = np.array([20,40,60,80])
Mirror2_travel = np.array([6e-6,11e-6,16e-6,21e-6])

def wavelength(fringe, Mirror2_travel):
    return ((2*Mirror2_travel)/(fringe))

print(f'The wavelength {np.mean(wavelength(fringe, Mirror2_travel)):1e}m')
# Out:
# The wavelength 5.520833e-07m

# %% [markdown]
# # Task 5.2.1
# As mirror two is moved through its travel the brightness of the fringes changes and the fringes become harder to distinguish from each other, this follows the same idea as seen the the Pre-lab question d. As in this question the graph of the intensity of a laser of multiple wavelengths against the path difference of the interfering waves is plotted and as the distance varies the intensity reaches minima and maxima.

# %% [markdown]
# # Task 5.2.2
#
# The total range travelled of mirror 2 is 353 $\mu m$ and therefore the distance for the centre of the fringes (0th order maximum) where the intensity is greatest is 176.5 $\mu m$.

# %%
def amplitude(d, lam):
    return (np.sin(2*np.pi*d/(lam)))
def totAmplitude(d, lam1, lam2):
    return (np.abs(amplitude(d, lam1) + amplitude(d, lam2)))**2

lam = 350e-9
lam2 = 350.3474e-9
d= np.linspace(174e-6, 178e-6, 100000)
plt.figure(figsize = (10,10))
plt.plot(d, totAmplitude(d, lam, lam2))
plt.title('Total Intensity vs. Distance', fontsize=title_size)
plt.xlabel(r'Distance ($\mu$m)', fontsize=axis_size)
#plt.xlim(0e-6, 40e-6)
plt.ylabel('Intensity (arb. units)', fontsize=axis_size)
plt.show()

# %% [markdown]
# # Task 5.2.3
#
# The difference in the wavelengths $\Delta \lambda$ calculated for a minima seperation of $353 \mu m$ is $0.3474 nm$. which coincides with the value given in the lab script fom the manufacturer (figure 15 of the lab script).

# %% [markdown]
# # Task 6.1
#
# For the red LED the total range travelled by mirror 2 is $19\mu m$ and therefore the distance for the centre of the fringes (0th order maximum) where the intensity is greatest is $9.5\mu m$. The difference in the wavelengths $\Delta \lambda$ calculated for a minima seperation of $19 \mu m$ is $4.83 nm$. Which seems consistent with the data given in figure17 of the lab script when taking a reading a Full Width Half Maximum (FWHM) of the red LED.

# %%
def amplitude(d, lam):
    return (np.sin(2*np.pi*d/(lam)))
def totAmplitude(d, lam1, lam2):
    return (np.abs(amplitude(d, lam1) + amplitude(d, lam2)))**2

lam = 300e-9
lam2 = 304.83e-9
d= np.linspace(7.5e-6, 10e-6, 100000)
plt.figure(figsize = (10,10))
plt.plot(d, totAmplitude(d, lam, lam2))
plt.title('Total Intensity vs. Distance', fontsize=title_size)
plt.xlabel(r'Distance ($\mu$m)', fontsize=axis_size)
#plt.xlim(0e-6, 40e-6)
plt.ylabel('Intensity (arb. units)', fontsize=axis_size)
plt.show()

# %% [markdown]
# # Task 7.1
#
# The fringes that appeared on the screen when a White LED was mounted in the Michelson Interferometer apparatus were fainter than that of the red LED or green laser. This is most likely due to the fact that the white LED emits light at a range of wavelengths, also because of this the fringes appeared more spread containing a range of visible colours, at different diffraction angles dependent on wavelength.

# %%
def amplitude(d, lam):
    return (np.sin(2*np.pi*d/(lam)))
def Int(d, lam):
    return (np.abs(amplitude(d, lam)))**2
def totInt(d, lam1, lam2, lam3):
    return (np.abs(amplitude(d, lam1) + amplitude(d, lam2) + amplitude(d, lam3)))**2
def ampratio(d,lam, lam2, lam3):
    return (Int(d, lam)/totInt(d, lam, lam2, lam3))
    
lamb = [450e-9, 550e-9, 650e-9]
d= np.linspace(-1e-6, 1e-6, 100000)

plt.figure(figsize = (10,20))
plt.subplot(3,1,1)
plt.plot(d, ampratio(d, lamb[0], lamb[1], lamb[2]))
plt.title('Amplitude Ratio vs. Distance', fontsize=title_size)
plt.xlabel(r'Distance ($\mu$m)', fontsize=axis_size)

plt.subplot(3,1,2)
plt.plot(d, ampratio(d, lamb[1], lamb[0], lamb[2]))
plt.title('Amplitude Ratio vs. Distance', fontsize=title_size)
plt.xlabel(r'Distance ($\mu$m)', fontsize=axis_size)

plt.subplot(3,1,3)
plt.plot(d, ampratio(d, lamb[2], lamb[0], lamb[1]))
plt.title('Amplitude Ratio vs. Distance', fontsize=title_size)
plt.xlabel(r'Distance ($\mu$m)', fontsize=axis_size)


plt.figure()

plt.plot(d, Int(d, lamb[0]),color = 'green')
plt.title('Amplitude Ratio vs. Distance', fontsize=title_size)
plt.xlabel(r'Distance ($\mu$m)', fontsize=axis_size)
plt.plot(d, Int(d, lamb[1]), color = 'yellow')
plt.plot(d, Int(d, lamb[2]), color = 'red')

# %% [markdown]
# # Task 8

# %%
angle = [1.25, 1.92,2.5,3,3.33,3.83]
fringes = [5,10,15,20,25,30]

def refractiveIndex(theta , lamb, t , N):
    2

plt.figure()
plt.scatter(angle, fringes, s=100,  marker='x', color='blue')
plt.title('Fringes vs. Angle', fontsize=title_size)
plt.xlabel(r'Angle (degrees)', fontsize=axis_size)
plt.ylabel('Fringes', fontsize=axis_size)
plt.show()
