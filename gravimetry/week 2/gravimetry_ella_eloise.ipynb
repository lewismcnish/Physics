# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy import stats
from scipy import integrate
from scipy import interpolate
from scipy import signal
from scipy import special
from scipy import constants
from scipy import linalg
from scipy import fftpack
from scipy import optimize
from scipy.optimize import curve_fit
from scipy.signal import find_peaks_cwt
from scipy.signal import argrelextrema
import fnmatch
import scipy as sp

# %%
data = np.loadtxt('eloisesdata.txt', skiprows=2)
t = data[:,0]
x = data[:,1]
# print(max(x))
x_true = x

x_t_lim = x_true[100:563]
t_lim = t[100:563]
# x_t_lim2 = x_true[750:1500]
# print(max(x_t_lim))
# print(max(x_t_lim2))
print(x)
# Out:
# [ 181.     180.9    180.9    180.9    180.9    180.9    180.8    181.1
#   181.1    181.5    181.     181.     181.     181.1    181.     181.1
#   181.     181.     181.     180.8    180.9    181.2    181.1    180.7
#   180.8    180.9    180.9    181.     181.     181.     181.     181.
#   181.     180.9    181.     181.     181.     181.     181.     181.
#   181.     181.     181.     181.     181.     181.     181.     181.
#   181.     181.     181.     181.     181.     181.     181.     181.
#   181.     181.     181.     181.1    182.3    185.     186.1    184.8
#   181.     177.1    172.     161.5    152.5    140.5    128.     116.
#   103.5     88.      74.12    58.32    42.81    26.85    11.17    -4.372
#   -19.49   -34.07   -47.95   -61.03   -73.83   -85.05   -95.37  -104.
#  -111.7   -117.9   -123.    -126.2   -128.1   -128.6   -127.5   -124.9
#  -120.9   -115.3   -108.3    -99.9    -90.7    -80.15   -68.49   -55.59
#   -42.13   -28.04   -13.31     1.884   17.34    32.73    48.39    63.84
#    78.62    93.07   107.1    120.2    132.2    143.2    154.3    162.8
#   170.1    175.9    179.7    182.2    182.9    182.     179.6    175.1
#   169.4    162.     153.3    143.2    131.7    119.6    106.4     92.72
#    78.19    63.21    47.81    32.47    17.       1.885  -13.     -27.56
#   -41.69   -54.92   -67.35   -78.91   -89.22   -98.14  -106.1   -112.9
#  -118.3   -121.9   -124.4   -125.1   -124.4   -122.2   -118.9   -114.
#  -107.9   -100.1    -91.27   -81.25   -70.16   -58.41   -45.38   -31.64
#   -17.47    -2.829   12.01    27.06    42.06    57.13    72.06    86.69
#   100.2    113.2    125.5    136.6    146.9    155.7    163.7    169.8
#   174.3    177.1    178.7    178.7    177.     173.9    168.8    162.6
#   154.8    145.6    135.3    123.9    111.6     98.35    84.63    68.38
#    53.29    38.29    23.01     8.153   -6.859  -20.97   -34.95   -47.97
#   -60.49   -72.08   -82.59   -92.1   -100.3   -107.1   -113.    -117.1
#  -120.1   -121.3   -121.2   -120.    -117.    -112.6   -107.2   -100.2
#   -91.99   -82.48   -72.11   -60.78   -48.44   -35.33   -21.66    -7.55
#     6.847   21.71    36.49    51.1     65.72    79.91    93.91   106.7
#   119.     130.5    141.     150.1    157.9    164.2    169.2    173.
#   174.9    175.3    174.2    171.7    167.4    161.7    154.7    146.2
#   136.3    125.7    114.     101.3     88.03    73.99    59.65    45.09
#    30.59    15.77     1.17   -13.01   -26.8    -40.1    -52.51   -64.09
#   -74.95   -84.97   -93.51  -100.9   -107.1   -112.    -115.6   -117.9
#  -118.4   -117.8   -115.2   -111.6   -106.7   -100.1    -92.61   -84.03
#   -74.1    -63.21   -51.52   -38.92   -25.96   -12.16     1.951   16.12
#    30.36    44.88    59.07    73.      86.54    99.91   112.1    123.3
#   133.9    143.2    151.4    158.3    163.9    167.9    170.5    171.5
#   170.9    168.9    165.3    160.1    153.7    146.     137.     126.9
#   115.8    103.8     91.07    77.9     63.93    49.78    35.45    20.89
#     6.707   -7.197  -20.79   -34.08   -46.65   -58.39   -69.19   -79.12
#   -87.95   -95.77  -102.2   -107.6   -111.5   -114.2   -115.4   -115.1
#  -113.6   -110.8   -106.5   -100.8    -93.92   -86.04   -76.94   -66.96
#   -56.     -43.91   -31.33   -18.1     -4.57     9.048   23.12    37.21
#    51.2     66.8     80.27    93.09   105.3    116.9    127.6    137.
#   145.6    153.     158.9    163.3    166.2    167.8    168.     166.6
#   163.9    159.3    153.6    146.4    138.     128.6    117.9    106.7
#    94.38    81.24    68.03    54.18    40.19    25.98    11.94    -1.941
#   -15.3    -28.31   -40.88   -52.62   -63.76   -73.69   -82.92   -90.91
#   -97.73  -103.2   -107.5   -110.3   -112.1   -112.2   -111.2   -108.8
#  -105.    -100.     -93.91   -86.68   -78.1    -68.32   -57.91   -46.81
#   -34.65   -22.11    -9.066    4.544   18.25    32.11    45.81    59.69
#    72.96    85.96    98.11   109.8    120.7    130.6    139.4    146.9
#   153.1    158.     162.     164.1    165.     164.1    162.     158.3
#   153.3    147.     138.7    129.8    119.9    108.9     97.35    85.05
#    72.01    58.47    44.86    30.99    17.25     3.688   -9.689  -22.78
#   -35.06   -46.91   -57.93   -68.09   -77.27   -85.42   -92.47   -98.05
#  -102.8   -106.1   -108.2   -109.    -108.5   -106.4   -103.2    -98.82
#   -93.26   -86.2    -78.45   -69.35   -59.25   -48.65   -37.06   -25.08
#   -12.22     0.814   14.17    27.41    40.94    54.14    67.36    80.01
#    92.23   104.     114.6    124.8    133.8    141.7    148.5    153.9
#   157.8    160.6    161.9    161.9    160.     157.     152.8    147.
#   140.1    132.     122.7    112.8    101.8     89.81    77.54    64.78
#    51.59    38.28    24.81    11.15    -2.141  -14.99   -27.28   -39.12
#   -50.27   -60.85   -70.13   -79.86   -87.21   -93.43   -98.09  -102.
#  -104.6   -105.9   -106.    -104.8   -102.1    -98.07   -92.97   -86.8
#   -79.23   -71.02   -61.57   -51.4    -40.27   -28.6    -16.33    -3.795
#     9.174   22.26    35.51    48.86    61.79    74.39    86.62   121.5
#   157.5    110.5     10.5    -78.5   -103.     -54.5     45.23   130.
#   152.   ]

# %%
# xx = str(x_true)

# xxx = np.zeros(10)
# fitered = fnmatch.filter(xx, '0.0?')
# filter = np.array(fitered)
# np.append(xxx,filter)

# # print(xx)


# import re
# regex = re.compile('0.0[0-9]')
# l = str(x_true)
# matches = [string for string in l if re.match(regex, string)]
# print(matches)

# %%
text_size_plots =20
text_size_axes = 17



def best_fit(x_t_lim, a, b, c,d):
    return a*(np.sin(b*x_t_lim+c)+d)

params, params_covariance = curve_fit(best_fit, t_lim, x_t_lim, p0=[100000, 3.1, 1, 1])
print(params)


plt.figure(figsize=(18,9))



plt.subplot(221)
plt.scatter(t,x,marker="x",color="b", linewidths= 1)
plt.grid(True)
plt.title("Position vs time", size=text_size_plots)
plt.xlabel("time (s)", size=15)
plt.ylabel("x Position (m)", size=15)

plt.subplot(222)
plt.scatter(t_lim,x_t_lim,marker="x",color="b",linewidths= 1)
plt.plot(t_lim, best_fit(t_lim, params[0], params[1], params[2],params[3]), color='r')
plt.grid(True)
# plt.title("Position vs time", size=text_size_plots)
plt.xlabel("Time (s)", size=text_size_axes)
plt.ylabel("x Position (mm)", size=text_size_axes)



plt.show()
# Out:
# [140.00123811   3.01616654   1.5893363    0.17224207]

# %%
x_peaks, peak = sp.signal.find_peaks(x, height=0.01, distance=30)
T1 = np.ones(0)
print(x_peaks)
print(peak)
for i in x_peaks:
    print(t[i])
    T1 = np.append(T1,t[i])

T = T1 - 0.3
print(T)
print(T[0])
print(T[1])
print(T[2]/2)
print(T[3]/3)
print(T[4]/4)
print(T[5]/5)
print(T[6]/6)
print(T[7]/7)
# print(T[8]/8)
# print(T[9]/9)
T_f = (T[0]+T[1]+T[2]/2+T[3]/3+T[4]/4)+T[5]/5+T[6]/6+T[7]/7/7
print()
print()
print()



print(f'The mean Period of motion is {T_f:.10f}s')
# Out:
# [  9  62 124 186 249 311 374 436 498 552]
# {'peak_heights': array([181.5, 186.1, 182.9, 178.7, 175.3, 171.5, 168. , 165. , 161.9,
#        157.5])}
# 0.3
# 2.1
# 4.167
# 6.233
# 8.333
# 10.4
# 12.5
# 14.567
# 16.633
# 18.433
# [ 0.     1.8    3.867  5.933  8.033 10.1   12.2   14.267 16.333 18.133]
# 0.0
# 1.8
# 1.9335
# 1.9776666666666667
# 2.00825
# 2.02
# 2.033333333333333
# 2.0381428571428573
#
#
#
# The mean Period of motion is 12.0639132653s

# %%
L = 1.081

g = (4*(np.pi**2)*L)/((T_f)**2)
print(f'The value of g is {g:.5f}m/s^2')
# Out:
# The value of g is 0.29323m/s^2

# %%
# v = np.ones(10)

# for k in (x_true):
#     if k == 0:
#         print(k)

# print(x_true)

# %%
avg_x = np.average(x)
x_scaled = (x-avg_x)



period_i = 0
period_f = 1548
t_p = t[period_i:period_f]
x_p = x[period_i:period_f]
t_x_p =argrelextrema(x_p, np.greater_equal)
x_p[argrelextrema(x_p, np.greater_equal)[0]]
# Out:
# array([  29.99 ,   29.99 ,   21.86 ,   11.9  ,    2.017,   -7.961,
#         -17.67 ,  -17.67 , -304.1  ])

# %%
rel_peak = np.zeros(period_f-period_i-1)
rel_peak_no = np.zeros(period_f-period_i-1)

for l in range (0,period_f-period_i-1):
    if (x_p[l-1]>x_p[l] and x_p[l+1]>x_p[l]):
        rel_peak[l]=x_p[l]
    elif (x_p[l-1]>x_p[l] and x_p[l+1]==x_p[l]) or (x_p[l-1]==x_p[l] and x_p[l+1]>x_p[l]):
            rel_peak_no[l]=x_p[l]
            
peak = np.nonzero(rel_peak)
no_peak = np.nonzero(rel_peak_no)
print ("identified peaks at",peak)
print("not sure on",no_peak)
# Out:
# identified peaks at (array([   0,    4,    8,   13,   22,   66,  172,  226,  241,  346,  348,
#         649,  671,  675,  694,  703,  705,  707,  713,  718,  722,  728,
#         734,  738,  741,  746,  749,  753,  758,  765,  767,  770,  778,
#         806,  834,  928,  937,  975,  985,  994, 1003, 1009, 1011, 1029,
#        1031, 1042, 1047, 1049, 1058, 1061, 1063, 1067, 1070, 1073, 1080,
#        1082, 1089, 1092, 1096, 1101, 1105, 1115, 1132, 1134, 1144, 1176,
#        1405, 1407, 1411, 1415, 1419, 1421, 1423, 1425, 1429, 1460, 1462,
#        1468, 1478, 1494, 1509, 1518], dtype=int64),)
# not sure on (array([  2, 668, 669, 679, 683, 685, 690, 691, 698, 700], dtype=int64),)

# %%
plt.figure(figsize=(12,9))

plt.subplot(312)
plt.plot(t_p,x_p,marker="o",color="b")
plt.grid(True)
plt.scatter(t_p[peak],x_p[peak],marker="x",color="r",s=300, label="correctly identified peak")
plt.scatter(t_p[no_peak],x_p[no_peak],marker="x",color="g",s=300, label="possible peak")
plt.title("Position with respect to time - Ten Periods", size=text_size_plots)
plt.xlabel("Time (s)", size=text_size_plots)
plt.ylabel("x position (m)", size=text_size_plots)


plt.subplot(313)
plt.plot(t_p,x_p,marker="o",color="b")
plt.grid(True)
plt.scatter(t_p[t_x_p],x_p[argrelextrema(x_p, np.greater_equal)[0]], marker="x",color="r",s=300, label="correctly identified peaks")
plt.title("Position with respect to time - identified peaks (numpy.argrelextrema version)")
plt.xlabel("Time (s)", size=text_size_plots)
plt.ylabel("x position (m)", size=text_size_plots)
plt.legend()
plt.ylim()

plt.tight_layout()
plt.show()

# %%
period = np.zeros(np.size(peak))
for z in range(0,np.size(peak)-1):
    period[z] = t_p[peak[0][z+1]]-t_p[peak[0][z]]
print("the period is:",period)
mode = np.median(period)
print("the mode is:",mode)
mean = np.mean(period)
print("the mean is:",mean)
# Out:
# the period is: [0.02834 0.02166 0.02    0.04667 0.20333 0.54334 0.26166 0.075   0.49667
#  0.00833 1.44    0.10334 0.01833 0.095   0.03833 0.00834 0.01166 0.025
#  0.02167 0.025   0.025   0.03333 0.01667 0.01167 0.03    0.01166 0.02167
#  0.02    0.03333 0.00834 0.01333 0.03667 0.13833 0.13833 0.445   0.05
#  0.18    0.04167 0.04167 0.05    0.025   0.00833 0.09167 0.01666 0.055
#  0.02    0.00834 0.04666 0.01167 0.00833 0.025   0.01334 0.01166 0.03834
#  0.01333 0.02833 0.01667 0.02167 0.02    0.02166 0.04167 0.07833 0.01334
#  0.04166 0.15834 1.09666 0.00834 0.01666 0.025   0.02167 0.00833 0.00834
#  0.00833 0.02    0.14667 0.00833 0.03333 0.045   0.085   0.07    0.04667
#  0.     ]
# the mode is: 0.02499999999999858
# the mean is: 0.08928865853658538

# %%
m = stats.mode(period)
print(m)
# Out:
# ModeResult(mode=array([0.00833]), count=array([5]))

# %%
# how to export ipynd to pdf
# https://stackoverflow.com/questions/3522893/possible-to-convert-ipython-notebook-into-latex-pdf
# Out:
#   Cell In[1], line 1
#     jupyter-nbconvert --to pdfviahtml example.ipynb
#                            ^
# SyntaxError: invalid syntax

# %%
jupyter nbconvert --to webpdf --no-input gravimetry_ella_eloise.ipynb
# Out:
#   Cell In[2], line 1
#     jupyter nbconvert --to webpdf --no-input gravimetry_ella_eloise.ipynb
#             ^
# SyntaxError: invalid syntax
